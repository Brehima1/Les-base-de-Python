# %% [markdown]
# <h1> Exercice 1 </h1>
#
# Vous êtes en charge de développer un système de réservation pour un cinéma. Le cinéma a une capacité de 40 sièges. Vous devez écrire un programme qui demande continuellement aux utilisateurs combien de billets ils souhaitent acheter, puis décompte ces billets du total disponible. Le programme doit s'arrêter lorsqu'il n'y a plus de sièges disponibles ou si l'utilisateur entre le nombre 0 (qui indique qu'il ne souhaite pas acheter de billets et qu'il s'agit de la fin de la queue).
#
# À la fin, le programme doit afficher le nombre total de billets vendus.
#
# <b> 1) Initialisation des Variables </b>
#
# - Définissez une variable pour la capacité totale du cinéma (40 sièges).
# - Définissez une variable pour compter le nombre total de billets vendus.
#
# <b> 2) Configuration de la Boucle while </b>
#
# - Commencez une boucle while qui s'exécute tant qu'il y a des sièges disponibles.
#
# <b> 3) Demande d'Achat de Billets </b>
#
# - À l'intérieur de la boucle, demandez à l'utilisateur combien de billets il souhaite acheter (via la méthode input)
# - Convertissez la réponse en un nombre entier.
#
# <b> 4) Conditions de Sortie </b>
#
# - Vérifiez si l'utilisateur a entré 0 (aucun achat). Si c'est le cas, interrompez la boucle avec break.
# - Vérifiez si le nombre de billets demandés est supérieur au nombre de sièges disponibles. Si c'est le cas, affichez un message d'erreur et redémarrez la boucle afin de demander à nouveau le nombre de places.
#
# <b> 5) Mise à Jour des Compteurs </b>
# - Déduisez le nombre de billets achetés de la capacité totale du cinéma.
# - Ajoutez le nombre de billets achetés au total des billets vendus.
#
# <b> 6) Affichage des Résultats </b>
# - À chaque itération, affichez le nombre de billets achetés et le nombre de sièges restants.
# - À la fin de la boucle, affichez le nombre total de billets vendus.
#
#
# <b> Important ! Point info sur la méthode Input</b>
#
# La méthode input permet d'afficher un champ de saisie. La valeur saisie peut être sauvegardée dans une variable.
# La valeur récupérée est pas défaut une string, il reste cependant possible de modifier son type.

# %%
prenom = input("Quel est votre prénom ?")
age = int(input(" Quel est votre age ?"))

print(f"Vous indiquez vous appeler {prenom} et avoir {age} ans")
# Out:
# Quel est votre prénom ? Brehima
#  Quel est votre age ? 28
# Vous indiquez vous appeler Brehima et avoir 28 ans

# %%
### 1 : Initialisation des variables
capacite_cinema = 40
billets_vendus  = 0
#2: Configuration de la boucle while

while  capacite_cinema >0:
    
    #3 : Demande d'achat  de billet
    achat = int(input("Combien de billets souhaitez-vous acheter? (Entrez 0 pour arreter)"))

    #4 : CONDITIONS DE SORTIE
    if achat ==0:
        print("Aucun achat . Arret  du programme")
        break

    if achat > capacite_cinema:
        print("Nombre de billets demandés supérieur à la capacité restante. Veuillez réessayer")
        continue

    #5 : Mise à jour des compteurs
    capacite_cinema -= achat
    billets_vendus += achat
    print(f"{achat} billet achetés. Il reste {capacite_cinema} sièges disponibles.")


#6: affichage des resultats

print("Nombre total de billets vendus : {billets_vendus}")
# Out:
# Combien de billets souhaitez-vous acheter? (Entrez 0 pour arreter) 35
# 35 billet achetés. Il reste 5 sièges disponibles.
# Combien de billets souhaitez-vous acheter? (Entrez 0 pour arreter) 7
# Nombre de billets demandés supérieur à la capacité restante. Veuillez réessayer
# Combien de billets souhaitez-vous acheter? (Entrez 0 pour arreter) 6
# Nombre de billets demandés supérieur à la capacité restante. Veuillez réessayer
# Combien de billets souhaitez-vous acheter? (Entrez 0 pour arreter) 5
# 5 billet achetés. Il reste 0 sièges disponibles.
# Nombre total de billets vendus : {billets_vendus}

# %% [markdown]
# <h1> Exercice 2 </h1>
#
# Vous êtes responsable du développement d'un programme pour une librairie. Cette librairie organise une foire aux livres et vous devez étiqueter chaque livre avec son prix et son numéro de série. Chaque livre de la foire a un prix fixé à 5 euros et vous avez une liste de 100 livres. Votre tâche est d'utiliser une boucle for pour créer une liste d'étiquettes pour chaque livre, indiquant son numéro de série (de 1 à 100) et son prix.
#
# <b> 1) Préparation de la Liste des Étiquettes </b>
# - Créez une liste vide pour stocker les étiquettes.
#
# <b> 2) Utilisation de la Boucle for avec range() </b>
# - Utilisez une boucle for en combinaison avec la fonction range() pour générer les numéros de série de 1 à 100.
#
# <b> 3) Création des Étiquettes </b>
# - Pour chaque numéro de série, créez une étiquette qui indique le numéro de série et le prix fixe du livre.
#
# <b> 4) Ajout des Étiquettes à la Liste</b>
# - Ajoutez chaque étiquette créée à la liste des étiquettes.

# %%
#1 Préparation de la Liste des Étiquettes
etiquettes = []
#2:Utilisation de la Boucle for avec range()
prix_livre = 5
for numero_serie  in range(1,101):
    #Création des Étiquettes 
    etiquette = f"Livre {numero_serie} - Prix: {prix_livre} euros"

    #Ajout des Étiquettes à la Liste
    etiquettes.append(etiquette)

#Afichage de toutes les etiquettes
for etiquette in etiquettes:
    print(etiquette)
# Out:
# Livre 1 - Prix: 5 euros
# Livre 2 - Prix: 5 euros
# Livre 3 - Prix: 5 euros
# Livre 4 - Prix: 5 euros
# Livre 5 - Prix: 5 euros
# Livre 6 - Prix: 5 euros
# Livre 7 - Prix: 5 euros
# Livre 8 - Prix: 5 euros
# Livre 9 - Prix: 5 euros
# Livre 10 - Prix: 5 euros
# Livre 11 - Prix: 5 euros
# Livre 12 - Prix: 5 euros
# Livre 13 - Prix: 5 euros
# Livre 14 - Prix: 5 euros
# Livre 15 - Prix: 5 euros
# Livre 16 - Prix: 5 euros
# Livre 17 - Prix: 5 euros
# Livre 18 - Prix: 5 euros
# Livre 19 - Prix: 5 euros
# Livre 20 - Prix: 5 euros
# Livre 21 - Prix: 5 euros
# Livre 22 - Prix: 5 euros
# Livre 23 - Prix: 5 euros
# Livre 24 - Prix: 5 euros
# Livre 25 - Prix: 5 euros
# Livre 26 - Prix: 5 euros
# Livre 27 - Prix: 5 euros
# Livre 28 - Prix: 5 euros
# Livre 29 - Prix: 5 euros
# Livre 30 - Prix: 5 euros
# Livre 31 - Prix: 5 euros
# Livre 32 - Prix: 5 euros
# Livre 33 - Prix: 5 euros
# Livre 34 - Prix: 5 euros
# Livre 35 - Prix: 5 euros
# Livre 36 - Prix: 5 euros
# Livre 37 - Prix: 5 euros
# Livre 38 - Prix: 5 euros
# Livre 39 - Prix: 5 euros
# Livre 40 - Prix: 5 euros
# Livre 41 - Prix: 5 euros
# Livre 42 - Prix: 5 euros
# Livre 43 - Prix: 5 euros
# Livre 44 - Prix: 5 euros
# Livre 45 - Prix: 5 euros
# Livre 46 - Prix: 5 euros
# Livre 47 - Prix: 5 euros
# Livre 48 - Prix: 5 euros
# Livre 49 - Prix: 5 euros
# Livre 50 - Prix: 5 euros
# Livre 51 - Prix: 5 euros
# Livre 52 - Prix: 5 euros
# Livre 53 - Prix: 5 euros
# Livre 54 - Prix: 5 euros
# Livre 55 - Prix: 5 euros
# Livre 56 - Prix: 5 euros
# Livre 57 - Prix: 5 euros
# Livre 58 - Prix: 5 euros
# Livre 59 - Prix: 5 euros
# Livre 60 - Prix: 5 euros
# Livre 61 - Prix: 5 euros
# Livre 62 - Prix: 5 euros
# Livre 63 - Prix: 5 euros
# Livre 64 - Prix: 5 euros
# Livre 65 - Prix: 5 euros
# Livre 66 - Prix: 5 euros
# Livre 67 - Prix: 5 euros
# Livre 68 - Prix: 5 euros
# Livre 69 - Prix: 5 euros
# Livre 70 - Prix: 5 euros
# Livre 71 - Prix: 5 euros
# Livre 72 - Prix: 5 euros
# Livre 73 - Prix: 5 euros
# Livre 74 - Prix: 5 euros
# Livre 75 - Prix: 5 euros
# Livre 76 - Prix: 5 euros
# Livre 77 - Prix: 5 euros
# Livre 78 - Prix: 5 euros
# Livre 79 - Prix: 5 euros
# Livre 80 - Prix: 5 euros
# Livre 81 - Prix: 5 euros
# Livre 82 - Prix: 5 euros
# Livre 83 - Prix: 5 euros
# Livre 84 - Prix: 5 euros
# Livre 85 - Prix: 5 euros
# Livre 86 - Prix: 5 euros
# Livre 87 - Prix: 5 euros
# Livre 88 - Prix: 5 euros
# Livre 89 - Prix: 5 euros
# Livre 90 - Prix: 5 euros
# Livre 91 - Prix: 5 euros
# Livre 92 - Prix: 5 euros
# Livre 93 - Prix: 5 euros
# Livre 94 - Prix: 5 euros
# Livre 95 - Prix: 5 euros
# Livre 96 - Prix: 5 euros
# Livre 97 - Prix: 5 euros
# Livre 98 - Prix: 5 euros
# Livre 99 - Prix: 5 euros
# Livre 100 - Prix: 5 euros

# %% [markdown]
# <h1> Exercice 3 </h1>
#
# Vous êtes en charge du développement d'un système pour un petit tournoi sportif. Vous avez un dictionnaire où chaque clé est le nom d'une équipe et chaque valeur est le nombre de points que l'équipe a gagnés jusqu'à présent.
#
# Votre tâche est d'utiliser une boucle for pour mettre à jour les points de chaque équipe en fonction de leurs performances dans les derniers matchs.

# %%
points_equipes = {
    "Équipe A": 25,
    "Équipe B": 30,
    "Équipe C": 22
}

resultats_matchs = {"Équipe A": 3, "Équipe B": 2, "Équipe C": 5}

# %%
for equipe ,  points_gagnes in resultats_matchs.items():
    points_equipes[equipe] +=points_gagnes
print(points_equipes)
# Out:
# {'Équipe A': 34, 'Équipe B': 36, 'Équipe C': 37}

# %% [markdown]
# <h1> Exercice 4 </h1>
#
# Vous travaillez sur un projet de gestion de données environnementales. Votre tâche est de traiter une liste de températures en degrés Celsius pour convertir ces températures en degrés Fahrenheit. Utilisez une compréhension de liste pour créer une nouvelle liste contenant les températures converties. Ensuite, filtrez cette liste pour ne conserver que les températures supérieures à 60 degrés Fahrenheit.
#
# Formule de Conversion
# La formule de conversion de Celsius en Fahrenheit est <b> F = (C × 9/5) + 32 </b>
#
#
# <b> 1) Conversion en Fahrenheit avec Compréhension de Liste </b>
#
# - Utilisez une compréhension de liste pour convertir chaque température en Fahrenheit.
#
# <b>2)  Filtrage des Températures </b>
#
# - Filtrez la nouvelle liste pour ne garder que les températures supérieures à 60 degrés Fahrenheit.

# %%
temperatures_celsius = [10, 15, 20, 25, 30]

# %%
#1 Conversion en Fahrenheit avec Compréhension de Liste 
temperatures_fahrenheit = [(c*9/5)+32 for c in temperatures_celsius]
# Filtrage des Températures 
temperatures_filtrees  = [f for f in temperatures_fahrenheit if f>60]

print("temperatures en fahrenheit:", temperatures_fahrenheit )
print("temperatures superieur à 60°F:", temperatures_filtrees)
# Out:
# temperatures en fahrenheit: [50.0, 59.0, 68.0, 77.0, 86.0]
# temperatures superieur à 60°F: [68.0, 77.0, 86.0]
